# %% [markdown]
# ### To write a python program get an integer input from a user. If the number is odd, then find the factorial of a number and find the number of digits in the factorial of the number. If the number is even, then check whether the given number is palindrome or not.

# %%
import math

num = int(input("Enter an integer: "))

if num % 2 == 0:
    temp = num
    rev = 0
    while temp > 0:
        rev = (rev * 10) + temp % 10
        temp //= 10

    if num == rev:
        print(num, "is a palindrome number")
    else:
        print(num, "is not a palindrome number")

else:
    fact = math.factorial(num)
    print("Factorial of", num, "is", fact)
    print("Number of digits in", num, "! is", len(str(fact)))
# Out:
# Factorial of 121 is 809429852527344373968162284544935082997082306309701607045776233628497660426640521713391773997910182738287074185078904956856663439318382745047716214841147650721760223072092160000000000000000000000000000
# Number of digits in 121 ! is 201

# %% [markdown]
# ### Given two strings, PRINT (YES or NO) whether the second string can be obtained from the first by deletion of none, one or more characters

# %%
def check(s1, s2):
    for i in s2:
        if i not in s1:
            return False
    return True

s1 = input("Enter first string: ")
s2 = input("Enter second string: ")

if check(s1, s2):
    print("YES")
else:
    print("NO")
# Out:
# NO
